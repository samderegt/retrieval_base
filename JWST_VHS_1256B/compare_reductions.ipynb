# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.io import fits

# %%
fig, ax = plt.subplots(figsize=(10,4))
for filename in ['nirspec_140h_1.dat', 'nirspec_140h_2.dat']:

    # wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/__{filename}', delimiter=',').T
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T
    # wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T

    # ax.plot(wave_M, flux_M, c='C3', lw=0.5, label='ERS')
    ax.plot(wave_AC, flux_AC, c='C0', lw=0.5, label='31-07-2025')
    ax.plot(wave, flux, c='k', lw=0.8, label='23-09-2025') 

    # ax.plot(wave, np.interp(wave, wave_M, flux_M)-flux, c='C3', lw=0.8, alpha=0.5)
    ax.plot(wave, np.interp(wave, wave_AC, flux_AC)-flux, c='C0', lw=0.8, alpha=0.5)

ax.legend(labelcolor='linecolor', ncol=2)
ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]')
ax.axhline(0, c='k', lw=0.8)
# ax.set_xlim(1.2,1.4)
plt.tight_layout()
# plt.savefig('./g140h.pdf', dpi=300)
plt.show()

fig, ax = plt.subplots(figsize=(10,4))
for filename in ['nirspec_235h_1.dat', 'nirspec_235h_2.dat']:

    # wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/__{filename}', delimiter=',').T
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T
    # wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T

    # ax.plot(wave_M, flux_M, c='C3', lw=0.5, label='ERS')
    ax.plot(wave_AC, flux_AC, c='C0', lw=0.5, label='31-07-2025')
    ax.plot(wave, flux, c='k', lw=0.8, label='23-09-2025')

    # ax.plot(wave, np.interp(wave, wave_M, flux_M)-flux, c='C3', lw=0.8, alpha=0.5)
    ax.plot(wave, np.interp(wave, wave_AC, flux_AC)-flux, c='C0', lw=0.8, alpha=0.5)

ax.legend(labelcolor='linecolor', ncol=2)
ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]')
ax.axhline(0, c='k', lw=0.8)
plt.tight_layout()
# plt.savefig('./g235h.pdf', dpi=300)
plt.show()

fig, ax = plt.subplots(figsize=(10,4))
for filename in ['nirspec_395h_1.dat', 'nirspec_395h_2.dat']:

    # wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    wave_AC, flux_AC, err_AC = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/__{filename}', delimiter=',').T
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T
    # wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T

    # ax.plot(wave_M, flux_M, c='C3', lw=0.5, label='ERS')
    ax.plot(wave_AC, flux_AC, c='C0', lw=0.5, label='31-07-2025')
    ax.plot(wave, flux, c='k', lw=0.8, label='23-09-2025')

    # ax.plot(wave, np.interp(wave, wave_M, flux_M)-flux, c='C3', lw=0.8, alpha=0.5)
    ax.plot(wave, np.interp(wave, wave_AC, flux_AC)-flux, c='C0', lw=0.8, alpha=0.5)

ax.legend(labelcolor='linecolor', ncol=2)
ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]')#, xlim=(5.0,5.2), ylim=(1e-16,3e-16))
ax.axhline(0, c='k', lw=0.8)
plt.tight_layout()
# plt.savefig('./g395h.pdf', dpi=300)
plt.show()

# %%
cmap = plt.get_cmap('tab20c')
kwargs = dict(alpha=1, linewidth=1)

fig, ax = plt.subplots(figsize=(10,4))
for i, filename in enumerate(['nirspec_140h_1.dat', 'nirspec_140h_2.dat', 'nirspec_235h_1.dat', 'nirspec_235h_2.dat', 'nirspec_395h_1.dat', 'nirspec_395h_2.dat']):

    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=cmap(i*2/20), **kwargs)

ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]')
# ax.set_xlim(1.63,1.9)
# ax.set_xlim(2.85,3.18)
# ax.axhline(0, c='k', lw=0.8)
# ax.set_xlim(1.2,1.4)
ax.set(yscale='log')
plt.tight_layout()
# plt.savefig('./g140h.pdf', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for filename in ['nirspec_395h_2.dat']:

    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    # ax.plot(wave, flux, c='C0', lw=1, label='31-07-2025')

    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/NIRSpec_ifu_reduction_23_09_2025/VHS1256b/{filename}', delimiter=',').T
    ax.plot(wave, flux, c='k', lw=1, label='23-09-2025', zorder=10)

    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T
    ax.plot(wave_M, flux_M, c='C3', lw=1, label='ERS')
    
    filename = 'miri_1A.dat'
    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave_M, flux_M, c='C2', lw=1, label='MIRI')

ax.legend(labelcolor='linecolor')
ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]', xlim=(4.85,5.3), ylim=(0.8e-16,2.8e-16))
ax.axhline(0, c='k', lw=0.8)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for filename in ['nirspec_395h_2.dat']:

    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    # wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_05_08_2025/{filename}', delimiter=',').T

    ax.plot(wave_M, flux_M, c='indianred', lw=0.5, label='ERS')
    ax.plot(wave, flux, c='k', lw=0.8, label='New reduction')
    ax.plot(wave, flux-np.interp(wave, wave_M, flux_M), c='k', lw=0.8, alpha=0.5, label='Diff')

ax.legend(labelcolor='linecolor')
ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]')
ax.axhline(0, c='k', lw=0.8)
ax.set(ylim=(-2e-17, 2e-17))
plt.tight_layout()
plt.savefig('./g395h.pdf', dpi=300)
plt.show()

# %%
cmap = plt.get_cmap('tab20c')
kwargs = dict(alpha=1, linewidth=1)

fig, ax = plt.subplots(figsize=(12,4))
for i, filename in enumerate(['nirspec_140h_1.dat', 'nirspec_140h_2.dat']):
    c = cmap((i+0)/20)
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['nirspec_235h_1.dat', 'nirspec_235h_2.dat']):
    c = cmap((i+4)/20)
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['nirspec_395h_1.dat', 'nirspec_395h_2.dat']):
    c = cmap((i+8)/20)
    wave, flux, err = np.loadtxt(f'/net/schenk/data2/regt/JWST_reductions/Miles_ea_2023/reduction_31_07_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]', yscale='log', xscale='log')
ax.set(ylim=(1e-16,1e-15))
#ax.set(xlim=(4.88,5.3), xscale='linear', ylim=(1e-16,3e-16), yscale='linear')
#ax.set(xlim=(1.65,1.9), xscale='linear', ylim=(2e-16,9e-16), yscale='linear')
#ax.set(xlim=(2.85,3.2), xscale='linear', ylim=(2e-16,6e-16), yscale='linear')
#ax.set(xlim=(5.5,6.8), xscale='linear', ylim=(4e-17,2e-16), yscale='linear')
#ax.set(xlim=(7.4,8.9), xscale='linear', ylim=(2e-17,1e-16), yscale='linear')
#ax.set(xlim=(8.9,12.0), xscale='linear', ylim=(1e-17,1e-16), yscale='linear')
plt.show()

# %%
cmap = plt.get_cmap('tab20c')
kwargs = dict(alpha=1, linewidth=1)

fig, ax = plt.subplots(figsize=(12,4))
for i, filename in enumerate(['nirspec_140h_1.dat', 'nirspec_140h_2.dat']):
    c = cmap((i+0)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['nirspec_235h_1.dat', 'nirspec_235h_2.dat']):
    c = cmap((i+4)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['nirspec_395h_1.dat', 'nirspec_395h_2.dat']):
    c = cmap((i+8)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['miri_1A.dat', 'miri_1B.dat', 'miri_1C.dat']):
    c = cmap((i+12)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['miri_2A.dat', 'miri_2B.dat', 'miri_2C.dat']):
    c = cmap((i+0)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['miri_3A.dat', 'miri_3B.dat', 'miri_3C.dat']):
    c = cmap((i+4)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

for i, filename in enumerate(['miri_4A.dat']):
    c = cmap((i+8)/20)
    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    ax.plot(wave, flux, c=c, **kwargs)

ax.set(xlabel='Wavelength [um]', ylabel='Flux [W/m^2/um]', yscale='log', xscale='log')
ax.set(ylim=(8e-19,1e-15))
#ax.set(xlim=(4.88,5.3), xscale='linear', ylim=(1e-16,3e-16), yscale='linear')
#ax.set(xlim=(1.65,1.9), xscale='linear', ylim=(2e-16,9e-16), yscale='linear')
#ax.set(xlim=(2.85,3.2), xscale='linear', ylim=(2e-16,6e-16), yscale='linear')
#ax.set(xlim=(5.5,6.8), xscale='linear', ylim=(4e-17,2e-16), yscale='linear')
#ax.set(xlim=(7.4,8.9), xscale='linear', ylim=(2e-17,1e-16), yscale='linear')
#ax.set(xlim=(8.9,12.0), xscale='linear', ylim=(1e-17,1e-16), yscale='linear')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for filename in ['miri_1A.dat', 'miri_1B.dat', 'miri_1C.dat']:

    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'./Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T

    ax.plot(wave_M, flux_M, c='indianred', lw=0.5, label='ERS')
    ax.plot(wave, flux, c='k', lw=0.8, label='New reduction')
plt.show()

fig, ax = plt.subplots(figsize=(12,4))
for filename in ['miri_2A.dat', 'miri_2B.dat', 'miri_2C.dat']:

    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'./Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T

    ax.plot(wave_M, flux_M, c='indianred', lw=0.5, label='ERS')
    ax.plot(wave, flux, c='k', lw=0.8, label='New reduction')
plt.show()

fig, ax = plt.subplots(figsize=(12,4))
for filename in ['miri_3A.dat', 'miri_3B.dat', 'miri_3C.dat']:

    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'./Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T

    ax.plot(wave_M, flux_M, c='indianred', lw=0.5, label='ERS')
    ax.plot(wave, flux, c='k', lw=0.8, label='New reduction')
plt.show()

fig, ax = plt.subplots(figsize=(12,4))
for filename in ['miri_4A.dat']:

    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'./Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T

    #ax.errorbar(wave_M, flux_M, yerr=err_M, c='indianred', label='ERS', fmt='.')
    ax.plot(wave, flux, c='k', lw=0.8, label='New reduction')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,10), nrows=3)
for i, filename in enumerate(['miri_1A.dat', 'miri_1B.dat', 'miri_1C.dat', 'miri_2A.dat', 'miri_2B.dat', 'miri_2C.dat', 'miri_3A.dat', 'miri_3B.dat', 'miri_3C.dat', 'miri_4A.dat']):

    wave, flux, err = np.loadtxt(f'./Miles_ea_2023/reduction_05_03_2025/{filename}', delimiter=',').T
    wave_M, flux_M, err_M = np.loadtxt(f'./Miles_ea_2023/ERS_reduction/{filename}', delimiter=',').T

    ax[0].plot(wave_M, flux_M, c='indianred', lw=0.5, label={'0':'ERS'}.get(str(i)))
    ax[0].plot(wave, flux, c='k', lw=0.8, label={'0':'New reduction'}.get(str(i)), alpha=0.5)

    ax[1].plot(wave_M, flux_M, c='indianred', lw=0.8, label={'0':'ERS'}.get(str(i)))
    ax[2].plot(wave, flux, c='k', lw=0.8, label={'0':'New reduction'}.get(str(i)))

ax[1].legend(); ax[2].legend()
ax[1].set(xlim=(7,12), ylim=(0,1e-16))
ax[2].set(xlabel='Wavelength [um]', xlim=(7,12), ylim=(0,1e-16))

plt.show()
