# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import utils

# %%
Res_1 = utils.RetrievalResults(prefix='../retrieval_outputs/no_bands_K_B_ret_7/test_')

# Perform the telluric cross-correlation
#wave_local, flux_local, _ = Res_1.get_model_spec(is_local=True, line_species='CH4_hargreaves_main_iso')
#wave_local, flux_local, _ = Res_1.get_model_spec(is_local=True, line_species='H2O_pokazatel_main_iso')
#wave_local, flux_local, _ = Res_1.get_model_spec(is_local=True, line_species='CO_main_iso')
wave_local, flux_local, _ = Res_1.get_model_spec(is_local=True, line_species='NH3_coles_main_iso')
rv, CCF, CCF_SNR = Res_1.get_telluric_CCF(wave_local, flux_local)
# Out:
#   analysing data from ../retrieval_outputs/no_bands_K_B_ret_7/test_.txt
# 100%|██████████| 1201/1201 [00:04<00:00, 290.26it/s]

# %%
plt.plot(rv, CCF_SNR)
