# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patheffects as pe
from matplotlib.ticker import FormatStrFormatter

import result_utils

# %%
name_A = 'Luhman 16A'; name_B = 'Luhman 16B'
color_A = '#FF622E'; color_B = '#396ED8'

lw_d = 0.8
lw_m = 1.0

res_alpha = 0.85

A = result_utils.RetrievalResults('../retrieval_outputs/freechem_K_A_ret_2/test_')
B = result_utils.RetrievalResults('../retrieval_outputs/freechem_K_B_ret_2/test_')
# Out:
# ../retrieval_outputs/freechem_K_A_ret_2/test_data
#   analysing data from ../retrieval_outputs/freechem_K_A_ret_2/test_.txt
# ../retrieval_outputs/freechem_K_B_ret_2/test_data
#   analysing data from ../retrieval_outputs/freechem_K_B_ret_2/test_.txt

# %%
A.load_components(['Chem'])
A.load_components(['Chem'])

# %%
#A.Chem['K2166_1'].VMRs_posterior['CH4'].shape
#result_utils.profile_quantiles(A.Chem['K2166_1'].VMRs_posterior['CH4'])
# Out:
# array([[5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06, 5.31888199e-06, 5.31888199e-06,
#         5.31888199e-06, 5.31888199e-06],
# ...
